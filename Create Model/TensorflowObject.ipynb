# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# !pip install -q Cython contextlib2 pillow lxml matplotlib PyDrive

# %%
# !pip install -q pycocotools

# %%
# %cd ./models/research
# Out:
# /content/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# %%
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.8: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# ...

# %%
# %cd ./object_detection/
# Out:
# /content/models/research/object_detection

# %%
# !pwd
# Out:
# /content/models/research/object_detection

# %%
import os
import shutil
import glob
import urllib.request
import tarfile

MODEL = 'faster_rcnn_inception_v2_coco_2018_01_28'
MODEL_FILE = MODEL + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
DEST_DIR = 'pretrained_model'

if not (os.path.exists(MODEL_FILE)):
  #opener = urllib.request()
  urllib.request.urlretrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
  shutil.rmtree(DEST_DIR)
os.rename(MODEL, DEST_DIR)

# %%
# !ls
# Out:
# anchor_generators		     matchers
# box_coders			     meta_architectures
# builders			     metrics
# CONTRIBUTING.md			     model_hparams.py
# core				     model_lib.py
# data				     model_lib_test.py
# data_decoders			     model_lib_v2.py
# dataset_tools			     model_lib_v2_test.py
# dockerfiles			     model_main.py
# eval_util.py			     models
# eval_util_test.py		     model_tpu_main.py
# exporter.py			     object_detection_tutorial.ipynb
# exporter_test.py		     predictors
# export_inference_graph.py	     pretrained_model
# export_tflite_ssd_graph_lib.py	     protos
# export_tflite_ssd_graph_lib_test.py  __pycache__
# export_tflite_ssd_graph.py	     README.md
# g3doc				     samples
# inference			     test_ckpt
# __init__.py			     test_data
# inputs.py			     test_images
# inputs_test.py			     tpu_exporters
# legacy				     utils

# %%
# %cd ..
# Out:
# /content/models/research

# %%
# !python setup.py build
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/model_main.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/inputs_test.py -> build/lib/object_detection
# copying object_detection/model_hparams.py -> build/lib/object_detection
# copying object_detection/model_tpu_main.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/model_lib_v2.py -> build/lib/object_detection
# ...

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/object_detection
# creating build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/faster_rcnn_box_coder.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# copying build/lib/object_detection/box_coders/mean_stddev_box_coder_test.py -> build/bdist.linux-x86_64/egg/object_detection/box_coders
# ...

# %%
# %cd object_detection
# Out:
# /content/models/research/object_detection

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/labelmap.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/labelmap.zip
#   inflating: labelmap.pbtxt

# %%
# !mv ./labelmap.pbtxt ./label_map.pbtxt
# !cat label_map.pbtxt
# Out:
# item {
# 	id: 1
# 	name: "Black_footed_Albatross"
# }
# item {
# 	id: 2
# 	name: "Laysan_Albatross"
# }
# item {
# 	id: 3
# 	name: "Sooty_Albatross"
# }
# item {
# 	id: 4
# 	name: "Groove_billed_Ani"
# }
# item {
# 	id: 5
# 	name: "Crested_Auklet"
# }
# item {
# 	id: 6
# 	name: "Least_Auklet"
# }
# item {
# 	id: 7
# 	name: "Parakeet_Auklet"
# }
# item {
# 	id: 8
# 	name: "Rhinoceros_Auklet"
# }
# item {
# 	id: 9
# 	name: "Brewer_Blackbird"
# }
# item {
# 	id: 10
# 	name: "Red_winged_Blackbird"
# }
# item {
# 	id: 11
# 	name: "Rusty_Blackbird"
# }
# item {
# 	id: 12
# 	name: "Yellow_headed_Blackbird"
# }
# item {
# 	id: 13
# 	name: "Bobolink"
# }
# item {
# 	id: 14
# 	name: "Indigo_Bunting"
# }
# item {
# 	id: 15
# 	name: "Lazuli_Bunting"
# }
# item {
# 	id: 16
# 	name: "Painted_Bunting"
# }
# item {
# 	id: 17
# 	name: "Cardinal"
# }
# item {
# 	id: 18
# 	name: "American_Goldfinch"
# }
# item {
# 	id: 19
# 	name: "Tree_Sparrow"
# }
# item {
# 	id: 20
# 	name: "American_Pipit"
# }
# ...

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/images.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/images.zip
#    creating: images/test/
#   inflating: images/test/Black_footed_Albatross_0029_2133609753.jpg
#   inflating: images/test/Black_footed_Albatross_0029_2133609753.xml
#   inflating: images/test/Black_footed_Albatross_0030_2444057668.jpg
#   inflating: images/test/Black_footed_Albatross_0030_2444057668.xml
#   inflating: images/test/Black_footed_Albatross_0031_2445546631.jpg
#   inflating: images/test/Black_footed_Albatross_0031_2445546631.xml
#   inflating: images/test/Black_footed_Albatross_0032_1465369016.jpg
#   inflating: images/test/Black_footed_Albatross_0032_1465369016.xml
#   inflating: images/test/Black_footed_Albatross_0033_2472109427.jpg
#   inflating: images/test/Black_footed_Albatross_0033_2472109427.xml
#   inflating: images/test/Black_footed_Albatross_0034_2134386992.jpg
#   inflating: images/test/Black_footed_Albatross_0034_2134386992.xml
# ...

# %%
# %cd images
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/images1.zip
# Out:
# [Errno 2] No such file or directory: 'images'
# /content/models/research/object_detection/images
# Archive:  /content/gdrive/My Drive/Colab Notebooks/images1.zip
#    creating: images/test/
#   inflating: images/test/American_Pipit_0023_2102280284.jpg
#   inflating: images/test/American_Pipit_0023_2102280284.xml
#   inflating: images/test/American_Pipit_0024_2409608440.jpg
#   inflating: images/test/American_Pipit_0024_2409608440.xml
#   inflating: images/test/American_Pipit_0025_1661960853.jpg
#   inflating: images/test/American_Pipit_0025_1661960853.xml
#   inflating: images/test/American_Pipit_0026_2409608430.jpg
#   inflating: images/test/American_Pipit_0026_2409608430.xml
#   inflating: images/test/American_Pipit_0027_459578874.jpg
#   inflating: images/test/American_Pipit_0027_459578874.xml
#   inflating: images/test/American_Pipit_0028_92915955.jpg
#   inflating: images/test/American_Pipit_0028_92915955.xml
#   inflating: images/test/American_Pipit_0029_2931534833.jpg
# ...

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/images3.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/images3.zip
#    creating: image3/test/
#   inflating: image3/test/American_Goldfinch_0020_468543137.jpg
#   inflating: image3/test/American_Goldfinch_0020_468543137.xml
#   inflating: image3/test/American_Goldfinch_0021_701242959.jpg
#   inflating: image3/test/American_Goldfinch_0021_701242959.xml
#   inflating: image3/test/American_Goldfinch_0022_468593407.jpg
#   inflating: image3/test/American_Goldfinch_0022_468593407.xml
#   inflating: image3/test/American_Goldfinch_0023_2098520281.jpg
#   inflating: image3/test/American_Goldfinch_0023_2098520281.xml
#   inflating: image3/test/American_Goldfinch_0024_2539527307.jpg
#   inflating: image3/test/American_Goldfinch_0024_2539527307.xml
#   inflating: image3/test/American_Goldfinch_0025_2548282174.jpg
#   inflating: image3/test/American_Goldfinch_0025_2548282174.xml
#   inflating: image3/test/Tree_Sparrow_0016_227402964.jpg
#   inflating: image3/test/Tree_Sparrow_0016_227402964.xml
# ...

# %%
# !cp image3/test/* test/
# !cp image3/train/* train/
# !cp images/test/* test/
# !cp images/train/* train/
# Out:
# 1044

# %%
# %cd ..
# Out:
# /content/models/research/object_detection

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/xml_to_csv.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/xml_to_csv.zip
#   inflating: xml_to_csv.py

# %%
# !python xml_to_csv.py
# Out:
# Successfully converted xml to csv.
# Successfully converted xml to csv.

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/tf.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/tf.zip
#   inflating: generate_tfrecord.py

# %%
# !cp images/train/*.jpg images/
# !python generate_tfrecord.py --csv_input=images/train_labels.csv --image_dir=images/train/ --output_path=train.record
# Out:
# WARNING:tensorflow:From generate_tfrecord.py:237: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:223: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W1015 16:00:14.007273 140311525394304 module_wrapper.py:139] From generate_tfrecord.py:223: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:182: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1015 16:00:14.735924 140311525394304 module_wrapper.py:139] From generate_tfrecord.py:182: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/models/research/object_detection/train.record

# %%
# !cp images/test/*.jpg images/
# !python generate_tfrecord.py --csv_input=images/test_labels.csv --image_dir=images/test/ --output_path=test.record
# Out:
# WARNING:tensorflow:From generate_tfrecord.py:237: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:223: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W1015 16:00:46.660923 140011826579328 module_wrapper.py:139] From generate_tfrecord.py:223: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:182: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W1015 16:00:46.923893 140011826579328 module_wrapper.py:139] From generate_tfrecord.py:182: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/models/research/object_detection/test.record

# %%
# !cat /content/models/research/object_detection/samples/configs/faster_rcnn_inception_v2_pets.config
# Out:
# # Faster R-CNN with Inception v2, configured for Oxford-IIIT Pets Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   faster_rcnn {
#     num_classes: 37
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 600
#         max_dimension: 1024
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_inception_v2'
#       first_stage_features_stride: 16
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
# ...

# %%
import re

#filename = '/content/datalab/pretrained_model/pipeline.config'
filename = '/content/models/research/object_detection/samples/configs/faster_rcnn_inception_v2_pets.config'
with open(filename) as f:
  s = f.read()
with open(filename, 'w') as f:
  
  s = re.sub('num_classes: 37', 'num_classes: 71', s)
  s = re.sub('num_examples: 1101', 'num_examples: 1044', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/model.ckpt', '/content/models/research/object_detection/pretrained_model/model.ckpt', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_faces_train.record-\?\?\?\?\?-of-00010', '/content/models/research/object_detection/train.record', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_faces_val.record-\?\?\?\?\?-of-00010', '/content/models/research/object_detection/test.record', s)
  s = re.sub('PATH_TO_BE_CONFIGURED/pet_label_map.pbtxt', '/content/models/research/object_detection/label_map.pbtxt', s)
  f.write(s)

# %%
# !mkdir custom_model

# %%
# !python ./legacy/train.py --logtostderr --train_dir=custom_model/ --pipeline_config_path=./samples/configs/faster_rcnn_inception_v2_pets.config
# Out:
# INFO:tensorflow:global step 60880: loss = 0.0466 (0.288 sec/step)
# I1015 22:04:53.781451 139727325398912 learning.py:507] global step 60880: loss = 0.0466 (0.288 sec/step)
# INFO:tensorflow:global step 60881: loss = 0.1830 (0.309 sec/step)
# I1015 22:04:54.093405 139727325398912 learning.py:507] global step 60881: loss = 0.1830 (0.309 sec/step)
# INFO:tensorflow:global step 60882: loss = 0.2019 (0.320 sec/step)
# I1015 22:04:54.415462 139727325398912 learning.py:507] global step 60882: loss = 0.2019 (0.320 sec/step)
# INFO:tensorflow:global step 60883: loss = 0.0931 (0.291 sec/step)
# I1015 22:04:54.708255 139727325398912 learning.py:507] global step 60883: loss = 0.0931 (0.291 sec/step)
# INFO:tensorflow:global step 60884: loss = 0.1251 (0.302 sec/step)
# I1015 22:04:55.011620 139727325398912 learning.py:507] global step 60884: loss = 0.1251 (0.302 sec/step)
# INFO:tensorflow:global step 60885: loss = 0.0435 (0.293 sec/step)
# ...

# %%
# !ls custom_model
# Out:
# checkpoint
# events.out.tfevents.1571155313.729c6cb293c0
# events.out.tfevents.1571158174.729c6cb293c0
# events.out.tfevents.1571158358.729c6cb293c0
# graph.pbtxt
# model.ckpt-52429.data-00000-of-00001
# model.ckpt-52429.index
# model.ckpt-52429.meta
# model.ckpt-54429.data-00000-of-00001
# model.ckpt-54429.index
# model.ckpt-54429.meta
# model.ckpt-56424.data-00000-of-00001
# model.ckpt-56424.index
# model.ckpt-56424.meta
# model.ckpt-58430.data-00000-of-00001
# model.ckpt-58430.index
# model.ckpt-58430.meta
# model.ckpt-60433.data-00000-of-00001
# model.ckpt-60433.index
# model.ckpt-60433.meta
# pipeline.config

# %%
# !unzip /content/gdrive/My\ Drive/Colab\ Notebooks/ig.zip
# Out:
# Archive:  /content/gdrive/My Drive/Colab Notebooks/ig.zip
# replace export_inference_graph.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: export_inference_graph.py

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path ./samples/configs/faster_rcnn_inception_v2_pets.config --trained_checkpoint_prefix custom_model/model.ckpt-60433 --output_directory inference_graph
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From export_inference_graph.py:156: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !ls
# Out:
# anchor_generators		     legacy
# box_coders			     matchers
# builders			     meta_architectures
# CONTRIBUTING.md			     metrics
# core				     model_hparams.py
# custom_model			     model_lib.py
# data				     model_lib_test.py
# data_decoders			     model_lib_v2.py
# dataset_tools			     model_lib_v2_test.py
# dockerfiles			     model_main.py
# eval_util.py			     models
# eval_util_test.py		     model_tpu_main.py
# exporter.py			     object_detection_tutorial.ipynb
# exporter_test.py		     predictors
# export_inference_graph.py	     pretrained_model
# export_tflite_ssd_graph_lib.py	     protos
# export_tflite_ssd_graph_lib_test.py  __pycache__
# export_tflite_ssd_graph.py	     README.md
# g3doc				     samples
# generate_tfrecord.py		     test_ckpt
# images				     test_data
# inference			     test_images
# inference_graph			     test.record
# __init__.py			     tpu_exporters
# inputs.py			     train.record
# inputs_test.py			     utils
# label_map.pbtxt			     xml_to_csv.py

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# !zip -r /content/models/research/object_detection/inference_graph.zip /content/models/research/object_detection/inference_graph
# Out:
#   adding: content/models/research/object_detection/inference_graph/ (stored 0%)
#   adding: content/models/research/object_detection/inference_graph/frozen_inference_graph.pb (deflated 10%)
#   adding: content/models/research/object_detection/inference_graph/pipeline.config (deflated 68%)
#   adding: content/models/research/object_detection/inference_graph/checkpoint (deflated 42%)
#   adding: content/models/research/object_detection/inference_graph/model.ckpt.index (deflated 70%)
#   adding: content/models/research/object_detection/inference_graph/model.ckpt.data-00000-of-00001 (deflated 7%)
#   adding: content/models/research/object_detection/inference_graph/model.ckpt.meta (deflated 95%)
#   adding: content/models/research/object_detection/inference_graph/saved_model/ (stored 0%)
#   adding: content/models/research/object_detection/inference_graph/saved_model/variables/ (stored 0%)
# ...

# %%
from google.colab import files
files.download("/content/models/research/object_detection/inference_graph.zip")
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 34152, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
# ...

# %%
uploaded = drive.CreateFile({'title': 'inference_graph.zip'})
uploaded.SetContentFile('inference_graph.zip')
uploaded.Upload()

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.0-rc3'

# %%
# !ls
# Out:
# anchor_generators		     matchers
# box_coders			     meta_architectures
# builders			     metrics
# CONTRIBUTING.md			     model_hparams.py
# core				     model_lib.py
# custom_model			     model_lib_test.py
# data				     model_lib_v2.py
# data_decoders			     model_lib_v2_test.py
# dataset_tools			     model_main.py
# dockerfiles			     models
# eval_util.py			     model_tpu_main.py
# eval_util_test.py		     object_detection_tutorial.ipynb
# exporter.py			     predictors
# exporter_test.py		     pretrained_model
# export_inference_graph.py	     protos
# export_tflite_ssd_graph_lib.py	     __pycache__
# export_tflite_ssd_graph_lib_test.py  README.md
# export_tflite_ssd_graph.py	     samples
# g3doc				     test_ckpt
# generate_tfrecord.py		     test_data
# images				     test_images
# inference			     test.record
# __init__.py			     tpu_exporters
# inputs.py			     train.record
# inputs_test.py			     utils
# label_map.pbtxt			     xml_to_csv.py
# legacy
